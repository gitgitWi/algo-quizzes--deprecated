# %% [markdown]
# ## 날짜 계산
#
# lv6. Silver V
#
# https://www.acmicpc.net/problem/1476
#
# 나머지 범위가 0부터가 아니고 1부터임에 주의

# %%
E,S,M = list (map (int, input().split()))

ans = 1
while True:
    if (ans-1) % 15 + 1 == E and (ans-1) % 28 +1 == S and (ans-1) % 19 +1 == M: 
        print (ans)
        break
    ans += 1
# Out:
# 16
